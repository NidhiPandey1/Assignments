# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from keras.models import Sequential
from keras.layers import Dense, Activation,Layer,Lambda

# %%
gasturbines = pd.read_csv(r'c:/Users/DELL/Downloads/gas_turbines.csv')
gasturbines
# Out:
#            AT      AP      AH    AFDP    GTEP     TIT     TAT     TEY     CDP  \
# 0      6.8594  1007.9  96.799  3.5000  19.663  1059.2  550.00  114.70  10.605
# 1      6.7850  1008.4  97.118  3.4998  19.728  1059.3  550.00  114.72  10.598
# 2      6.8977  1008.8  95.939  3.4824  19.779  1059.4  549.87  114.71  10.601
# 3      7.0569  1009.2  95.249  3.4805  19.792  1059.6  549.99  114.72  10.606
# 4      7.3978  1009.7  95.150  3.4976  19.765  1059.7  549.98  114.72  10.612
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 15034  9.0301  1005.6  98.460  3.5421  19.164  1049.7  546.21  111.61  10.400
# 15035  7.8879  1005.9  99.093  3.5059  19.414  1046.3  543.22  111.78  10.433
# 15036  7.2647  1006.3  99.496  3.4770  19.530  1037.7  537.32  110.19  10.483
# 15037  7.0060  1006.8  99.008  3.4486  19.377  1043.2  541.24  110.74  10.533
# 15038  6.9279  1007.2  97.533  3.4275  19.306  1049.9  545.85  111.58  10.583
#
#            CO     NOX
# 0      3.1547  82.722
# 1      3.2363  82.776
# 2      3.2012  82.468
# 3      3.1923  82.670
# 4      3.2484  82.311
# ...       ...     ...
# 15034  4.5186  79.559
# 15035  4.8470  79.917
# 15036  7.9632  90.912
# 15037  6.2494  93.227
# 15038  4.9816  92.498
#
# [15039 rows x 11 columns]

# %%
gasturbines.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15039 entries, 0 to 15038
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AT      15039 non-null  float64
#  1   AP      15039 non-null  float64
#  2   AH      15039 non-null  float64
#  3   AFDP    15039 non-null  float64
#  4   GTEP    15039 non-null  float64
#  5   TIT     15039 non-null  float64
#  6   TAT     15039 non-null  float64
#  7   TEY     15039 non-null  float64
#  8   CDP     15039 non-null  float64
#  9   CO      15039 non-null  float64
#  10  NOX     15039 non-null  float64
# dtypes: float64(11)
# memory usage: 1.3 MB

# %%
gasturbines.describe()
# Out:
#                  AT           AP            AH          AFDP          GTEP  \
# count  15039.000000  15039.00000  15039.000000  15039.000000  15039.000000
# mean      17.764381   1013.19924     79.124174      4.200294     25.419061
# std        7.574323      6.41076     13.793439      0.760197      4.173916
# min        0.522300    985.85000     30.344000      2.087400     17.878000
# 25%       11.408000   1008.90000     69.750000      3.723900     23.294000
# 50%       18.186000   1012.80000     82.266000      4.186200     25.082000
# 75%       23.862500   1016.90000     90.043500      4.550900     27.184000
# max       34.929000   1034.20000    100.200000      7.610600     37.402000
#
#                 TIT           TAT           TEY           CDP            CO  \
# count  15039.000000  15039.000000  15039.000000  15039.000000  15039.000000
# mean    1083.798770    545.396183    134.188464     12.102353      1.972499
# std       16.527806      7.866803     15.829717      1.103196      2.222206
# min     1000.800000    512.450000    100.170000      9.904400      0.000388
# 25%     1079.600000    542.170000    127.985000     11.622000      0.858055
# 50%     1088.700000    549.890000    133.780000     12.025000      1.390200
# 75%     1096.000000    550.060000    140.895000     12.578000      2.160400
# max     1100.800000    550.610000    174.610000     15.081000     44.103000
#
#                 NOX
# count  15039.000000
# mean      68.190934
# std       10.470586
# min       27.765000
# 25%       61.303500
# 50%       66.601000
# 75%       73.935500
# max      119.890000

# %%
gasturbines[gasturbines.duplicated()]
# Out:
# Empty DataFrame
# Columns: [AT, AP, AH, AFDP, GTEP, TIT, TAT, TEY, CDP, CO, NOX]
# Index: []

# %%
for i in gasturbines.columns:
    sns.boxplot(gasturbines[i])
    plt.xlabel(i)
    plt.show()

# %%
for i in gasturbines.columns:
    sns.histplot(gasturbines[i])
    plt.xlabel(i)
    plt.show()

# %%
sns.distplot(gasturbines['TEY'])
# Out:
# <Axes: xlabel='TEY', ylabel='Density'>

# %%
sns.histplot(gasturbines['TEY'])
# Out:
# <Axes: xlabel='TEY', ylabel='Count'>

# %%
plt.figure(figsize=(12,8))
sns.heatmap(gasturbines.corr(),vmin=-1,vmax=1,annot=True)
plt.show()

# %%
# Finding Categorical Data :
print("The AT column")
print(gasturbines['AT'].value_counts())
print()
print("The AP column")
print(gasturbines['AP'].value_counts())
print()
print("The AH column")
print(gasturbines['AH'].value_counts())
print()
print("The AFDP column")
print(gasturbines['AFDP'].value_counts())
print()
print("The GTEP column")
print(gasturbines['GTEP'].value_counts())
print()
print("The TIT column")
print(gasturbines['TIT'].value_counts())
print()
print("The TAT column")
print(gasturbines['TAT'].value_counts())
print()
print("The TEY column")
print(gasturbines['TEY'].value_counts())
print()
print("The CDP column")
print(gasturbines['CDP'].value_counts())
print()
print("The CO column")
print(gasturbines['CO'].value_counts())
print()
print("The NOX column")
print(gasturbines['NOX'].value_counts())
print()
# Out:
# The AT column
# AT
# 20.1350    5
# 25.9690    5
# 14.0430    5
# 20.1690    5
# 20.7200    5
#           ..
# 17.7090    1
# 17.2890    1
# 17.1100    1
# 17.2850    1
# 6.9279     1
# Name: count, Length: 12086, dtype: int64
#
# The AP column
# AP
# 1011.80    129
# 1012.10    127
# 1011.90    121
# 1010.80    119
# 1013.60    118
#           ...
# 996.30       1
# 998.02       1
# 998.48       1
# 998.88       1
# 1029.80      1
# Name: count, Length: 540, dtype: int64
#
# The AH column
# AH
# 100.140    31
# 100.150    29
# 100.110    28
# 100.120    24
# 100.130    19
#            ..
# 57.187      1
# 60.104      1
# 62.370      1
# 67.608      1
# 97.533      1
# Name: count, Length: 12637, dtype: int64
#
# The AFDP column
# AFDP
# 4.5032    7
# 4.4361    6
# 3.8837    6
# 4.4273    6
# 4.2500    6
#          ..
# 4.5599    1
# 4.6085    1
# 4.5880    1
# 4.5110    1
# 3.4770    1
# Name: count, Length: 11314, dtype: int64
#
# The GTEP column
# GTEP
# 25.487    9
# 25.552    9
# 24.308    9
# 24.288    9
# 24.361    9
#          ..
# 25.686    1
# 22.525    1
# 25.485    1
# 20.980    1
# 19.164    1
# Name: count, Length: 8234, dtype: int64
#
# The TIT column
# TIT
# 1100.0    761
# 1099.9    598
# 1100.1    592
# 1100.2    415
# 1099.8    368
#          ...
# 1036.0      1
# 1048.8      1
# 1024.6      1
# 1031.3      1
# 1037.7      1
# Name: count, Length: 706, dtype: int64
#
# The TAT column
# TAT
# 550.01    270
# 550.00    268
# 550.04    266
# 550.03    253
# 549.98    252
#          ...
# 533.65      1
# 528.40      1
# 524.54      1
# 532.56      1
# 545.85      1
# Name: count, Length: 2340, dtype: int64
#
# The TEY column
# TEY
# 133.74    150
# 133.78    148
# 133.67    143
# 133.76    142
# 133.79    127
#          ...
# 126.30      1
# 130.81      1
# 144.89      1
# 121.46      1
# 115.52      1
# Name: count, Length: 4207, dtype: int64
#
# The CDP column
# CDP
# 12.165    26
# 12.122    25
# 11.806    22
# 12.126    22
# 11.934    22
#           ..
# 10.003     1
# 10.031     1
# 13.189     1
# 10.021     1
# 11.685     1
# Name: count, Length: 3611, dtype: int64
#
# The CO column
# CO
# 1.33180    5
# 1.31910    5
# 1.23980    5
# 1.48320    5
# 1.28460    4
#           ..
# 0.28912    1
# 1.76560    1
# 1.51170    1
# 1.94150    1
# 4.98160    1
# Name: count, Length: 13096, dtype: int64
#
# The NOX column
# NOX
# 60.380    103
# 56.644      6
# 66.012      6
# 61.579      6
# 66.702      5
#          ...
# 64.898      1
# 65.574      1
# 65.475      1
# 65.404      1
# 92.498      1
# Name: count, Length: 11996, dtype: int64

# %%
 #Defining Predictors and Target Variables :
predictors_1 = gasturbines.iloc[:,0:7]
predictors_2 = gasturbines.iloc[:,8:]
predictors = predictors_1.join(predictors_2)

target = gasturbines.iloc[:,7]

# %%
predictors
# Out:
#            AT      AP      AH    AFDP    GTEP     TIT     TAT     CDP      CO  \
# 0      6.8594  1007.9  96.799  3.5000  19.663  1059.2  550.00  10.605  3.1547
# 1      6.7850  1008.4  97.118  3.4998  19.728  1059.3  550.00  10.598  3.2363
# 2      6.8977  1008.8  95.939  3.4824  19.779  1059.4  549.87  10.601  3.2012
# 3      7.0569  1009.2  95.249  3.4805  19.792  1059.6  549.99  10.606  3.1923
# 4      7.3978  1009.7  95.150  3.4976  19.765  1059.7  549.98  10.612  3.2484
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 15034  9.0301  1005.6  98.460  3.5421  19.164  1049.7  546.21  10.400  4.5186
# 15035  7.8879  1005.9  99.093  3.5059  19.414  1046.3  543.22  10.433  4.8470
# 15036  7.2647  1006.3  99.496  3.4770  19.530  1037.7  537.32  10.483  7.9632
# 15037  7.0060  1006.8  99.008  3.4486  19.377  1043.2  541.24  10.533  6.2494
# 15038  6.9279  1007.2  97.533  3.4275  19.306  1049.9  545.85  10.583  4.9816
#
#           NOX
# 0      82.722
# 1      82.776
# 2      82.468
# 3      82.670
# 4      82.311
# ...       ...
# 15034  79.559
# 15035  79.917
# 15036  90.912
# 15037  93.227
# 15038  92.498
#
# [15039 rows x 10 columns]

# %%
target
# Out:
# 0        114.70
# 1        114.72
# 2        114.71
# 3        114.72
# 4        114.72
#           ...
# 15034    111.61
# 15035    111.78
# 15036    110.19
# 15037    110.74
# 15038    111.58
# Name: TEY, Length: 15039, dtype: float64

# %%
# Splitting data into Train and Test Data Set :
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(predictors,target,test_size=0.3,random_state=0)

# %%
ann = Sequential()

# %%
#input layer + 1st hidden layer
ann.add(Dense(units=6,activation='relu'))
#adding 2nd layer
ann.add(Dense(units =6,activation='relu'))
#adding the output layer
ann.add(Dense(units=1))


#Training the ANN
#compililng the ANN
ann.compile(optimizer='adam',loss = 'mean_squared_error')

# %%
history = ann.fit(x_train,y_train,batch_size=32, epochs= 100)
# Out:
# Epoch 1/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 4876.6172
# Epoch 2/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 201.1344
# Epoch 3/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 162.1041
# Epoch 4/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 122.6597
# Epoch 5/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 80.6264
# Epoch 6/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 52.4601
# Epoch 7/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 29.1844
# Epoch 8/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 16.3534
# Epoch 9/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.9593
# Epoch 10/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.8691
# Epoch 11/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.5410
# Epoch 12/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.6102
# Epoch 13/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.8372
# Epoch 14/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.0646
# Epoch 15/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.6475
# Epoch 16/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 0s 986us/step - loss: 2.3548
# Epoch 17/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 0s 999us/step - loss: 1.9790
# Epoch 18/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.9450
# Epoch 19/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6418
# Epoch 20/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.7513
# Epoch 21/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5162
# Epoch 22/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6389
# Epoch 23/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6474
# Epoch 24/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5589
# Epoch 25/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.8596
# Epoch 26/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4283
# Epoch 27/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6402
# Epoch 28/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5632
# Epoch 29/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3617
# Epoch 30/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4200
# Epoch 31/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5936
# Epoch 32/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.7447
# Epoch 33/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4575
# Epoch 34/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6110
# Epoch 35/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5230
# Epoch 36/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5318
# Epoch 37/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4211
# Epoch 38/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4661
# Epoch 39/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6256
# Epoch 40/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5311
# Epoch 41/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3488
# Epoch 42/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 0s 977us/step - loss: 1.3156
# Epoch 43/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2750
# Epoch 44/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4092
# Epoch 45/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2758
# Epoch 46/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3163
# Epoch 47/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5396
# Epoch 48/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5554
# Epoch 49/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3326
# Epoch 50/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3469
# Epoch 51/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1666
# Epoch 52/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5389
# Epoch 53/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.7966
# Epoch 54/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3550
# Epoch 55/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3019
# Epoch 56/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5643
# Epoch 57/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3095
# Epoch 58/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3242
# Epoch 59/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4394
# Epoch 60/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3600
# Epoch 61/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2856
# Epoch 62/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 0s 970us/step - loss: 1.4303
# Epoch 63/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4117
# Epoch 64/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3578
# Epoch 65/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3744
# Epoch 66/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3143
# Epoch 67/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2648
# Epoch 68/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4569
# Epoch 69/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4399
# Epoch 70/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3758
# Epoch 71/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3623
# Epoch 72/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.5966
# Epoch 73/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5052
# Epoch 74/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5554
# Epoch 75/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3107
# Epoch 76/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3315
# Epoch 77/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4833
# Epoch 78/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4129
# Epoch 79/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4102
# Epoch 80/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2670
# Epoch 81/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.3683
# Epoch 82/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4792
# Epoch 83/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.4053
# Epoch 84/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2572
# Epoch 85/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2936
# Epoch 86/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2540
# Epoch 87/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4935
# Epoch 88/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3433
# Epoch 89/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4105
# Epoch 90/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3306
# Epoch 91/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4619
# Epoch 92/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2659
# Epoch 93/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3656
# Epoch 94/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3139
# Epoch 95/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2381
# Epoch 96/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2678
# Epoch 97/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4926
# Epoch 98/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4636
# Epoch 99/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4060
# Epoch 100/100
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4752

# %%
pred_train = ann.predict(np.array(x_train))
pred_train = pd.Series([i[0] for i in pred_train])
pred_train
# Out:
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 0        124.961220
# 1        134.126709
# 2        135.033020
# 3        150.930481
# 4        134.976089
#             ...
# 10522    113.130852
# 10523    134.384613
# 10524    153.859314
# 10525    126.857689
# 10526    110.609642
# Length: 10527, dtype: float32

# %%
# evaluate the model
scores = ann.evaluate(predictors, target)
print("%s: %.2f%%" % (ann.metrics_names[0], scores*100))
# Out:
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 1s 949us/step - loss: 2.2184
# loss: 183.66%
